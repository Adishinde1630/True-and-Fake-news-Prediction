# %%
import numpy as np
import pandas as pd

# %%
true_info=pd.read_csv("True.csv")
true_info
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
true_info.isnull().any()
# Out:
# title      False
# text       False
# subject    False
# date       False
# true       False
# dtype: bool

# %%
fake_info=pd.read_csv("fake.csv")
fake_info
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
fake_info.isnull().any()
# Out:
# title      False
# text       False
# subject    False
# date       False
# fake       False
# dtype: bool

# %%
true_info["true"]= 1

# %%
true_info.to_csv("True.csv", index=False)

# %%
true_info = pd.read_csv("True.csv")
true_info
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
true_info.isnull()
# Out:
#        title   text  subject   date   true
# 0      False  False    False  False  False
# 1      False  False    False  False  False
# 2      False  False    False  False  False
# 3      False  False    False  False  False
# 4      False  False    False  False  False
# ...      ...    ...      ...    ...    ...
# 21412  False  False    False  False  False
# 21413  False  False    False  False  False
# 21414  False  False    False  False  False
# 21415  False  False    False  False  False
# 21416  False  False    False  False  False
#
# [21417 rows x 5 columns]

# %%
fake_info["fake"]= 0

# %%
fake_info.to_csv("fake.csv", index=False)

# %%
fake_info = pd.read_csv("fake.csv")
fake_info
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
fake_info.isnull()
# Out:
#        title   text  subject   date   fake
# 0      False  False    False  False  False
# 1      False  False    False  False  False
# 2      False  False    False  False  False
# 3      False  False    False  False  False
# 4      False  False    False  False  False
# ...      ...    ...      ...    ...    ...
# 23476  False  False    False  False  False
# 23477  False  False    False  False  False
# 23478  False  False    False  False  False
# 23479  False  False    False  False  False
# 23480  False  False    False  False  False
#
# [23481 rows x 5 columns]

# %%
combined_df = pd.concat([true_info, fake_info], axis=0, ignore_index=True)
combined_df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
combined_df.isnull().value_counts()
# Out:
# title  text   subject  date   true   fake
# False  False  False    False  True   False    23481
#                               False  True     21417
# Name: count, dtype: int64

# %%
combined_df["fake"].isnull().value_counts()
# Out:
# fake
# False    23481
# True     21417
# Name: count, dtype: int64

# %%
combined_df["true"].isnull().value_counts()
# Out:
# true
# True     23481
# False    21417
# Name: count, dtype: int64

# %%
combined_df["label"] = combined_df["true"].fillna(0).astype(int)

# %%
combined_df = combined_df.drop(columns=["true", "fake"])
combined_df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
combined_df = combined_df.dropna().reset_index(drop=True)

# %%
combined_df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
combined_df.isnull().any()
# Out:
# title      False
# text       False
# subject    False
# date       False
# label      False
# dtype: bool

# %%
! pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------- ----- 1.3/1.5 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 7.3 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [regex]
#    ------------- -------------------------- 1/3 [regex]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
# ...

# %%
import pandas as pd
import numpy as np
import re
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# sklearn feature extraction

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Data preprocessing and Model Building

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score

# Visualization

import matplotlib.pyplot as plt
import seaborn as sns

# Progess bars for loops and apply
from tqdm import  tqdm
tqdm.pandas() # Enable Progess_apply

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\GORAKH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\GORAKH\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\GORAKH\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
combined_df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
sns.countplot(x="label", data = combined_df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
x = combined_df[["text"]]
y = combined_df["label"]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y, test_size= 0.2, random_state= 42)

# %%
X_train.shape
# Out:
# (35918, 1)

# %%
Y_train.shape
# Out:
# (35918,)

# %%
X_test.shape
# Out:
# (8980, 1)

# %%
Y_test.shape
# Out:
# (8980,)

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(raw_text, flag):
    sentence = re.sub('[^a-zA-Z]', " ", raw_text)
    sentence = sentence.lower()
    tokens = sentence.split()
    clean_tokens = [t for t in tokens if not t in stopwords.words("english")]
    if(flag == 'stem'):
        clean_tokens = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([' '.join(clean_tokens), len(clean_tokens)])

# %%
combined_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
train_df = X_train['text'].progress_apply(lambda x: preprocess(x, 'stem'))
# Out:
# 100%|██████████| 35918/35918 [1:36:02<00:00,  6.23it/s]

# %%
train_df.head()
# Out:
#                                                        0    1
# 36335  stori first long seri hillari lie expos next c...  142
# 12384  pari reuter leader european union remain membe...   57
# 24419  star war icon mark hamil previous mock donald ...  206
# 24740  whiner chief struck yet anoth earli morn twitt...  310
# 27039  donald trump much foreign polici experi love g...  237

# %%
train_df.columns=['clean_text_stem','text_length_stem']
train_df.head()
# Out:
#                                          clean_text_stem  text_length_stem
# 36335  stori first long seri hillari lie expos next c...               142
# 12384  pari reuter leader european union remain membe...                57
# 24419  star war icon mark hamil previous mock donald ...               206
# 24740  whiner chief struck yet anoth earli morn twitt...               310
# 27039  donald trump much foreign polici experi love g...               237

# %%
x_train=pd.concat([X_train,train_df],axis=1)
x_train.head()
# Out:
#                                                     text  \
# 36335  This story is from 2006 and is the first in a ...
# 12384  PARIS (Reuters) - The leaders of the European ...
# 24419  Star Wars icon Mark Hamill previously mocked D...
# 24740  The whiner-in-chief struck again with yet anot...
# 27039  Donald Trump doesn t have much foreign policy ...
#
#                                          clean_text_stem  text_length_stem
# 36335  stori first long seri hillari lie expos next c...               142
# 12384  pari reuter leader european union remain membe...                57
# 24419  star war icon mark hamil previous mock donald ...               206
# 24740  whiner chief struck yet anoth earli morn twitt...               310
# 27039  donald trump much foreign polici experi love g...               237

# %%
train_df.columns=['clean_text_lemma','text_length_lemma']
train_df.head()
# Out:
#                                         clean_text_lemma  text_length_lemma
# 36335  stori first long seri hillari lie expos next c...                142
# 12384  pari reuter leader european union remain membe...                 57
# 24419  star war icon mark hamil previous mock donald ...                206
# 24740  whiner chief struck yet anoth earli morn twitt...                310
# 27039  donald trump much foreign polici experi love g...                237

# %%
X_train=pd.concat([X_train,train_df],axis=1)

# %%
X_train.head()
# Out:
#                                                     text  \
# 36335  This story is from 2006 and is the first in a ...
# 12384  PARIS (Reuters) - The leaders of the European ...
# 24419  Star Wars icon Mark Hamill previously mocked D...
# 24740  The whiner-in-chief struck again with yet anot...
# 27039  Donald Trump doesn t have much foreign policy ...
#
#                                         clean_text_lemma  text_length_lemma
# 36335  stori first long seri hillari lie expos next c...                142
# 12384  pari reuter leader european union remain membe...                 57
# 24419  star war icon mark hamil previous mock donald ...                206
# 24740  whiner chief struck yet anoth earli morn twitt...                310
# 27039  donald trump much foreign polici experi love g...                237

# %% [markdown]
# ## Converting text to numerical vector

# %%
vocab=CountVectorizer()
X_train_bow=vocab.fit_transform(X_train['clean_text_lemma'])

# %%
X_train_bow
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 5430021 stored elements and shape (35918, 81084)>

# %%
vocab=CountVectorizer()
X_train_bow=vocab.fit_transform(X_train['text'])

# %%
X_train_bow
# Out:
# <35918x111440 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7513906 stored elements in Compressed Sparse Row format>

# %%
print("Total unique Words:",len(vocab.vocabulary_))
print("Type Train Features:",type(X_train_bow))
print("Shape of input data:",X_train_bow.shape)
# Out:
# Total unique Words: 81084
# Type Train Features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (35918, 81084)

# %%
X_test['text']
# Out:
# 22216    Donald Trump s White House is in chaos, and th...
# 27917    Now that Donald Trump is the presumptive GOP n...
# 25007    Mike Pence is a huge homophobe. He supports ex...
# 1377     SAN FRANCISCO (Reuters) - California Attorney ...
# 32476    Twisted reasoning is all that comes from Pelos...
#                                ...
# 42119    Hillary s over-the-top plan to tax the consume...
# 4068     WASHINGTON (Reuters) - President Donald Trump ...
# 22498    Donald Trump s White House is the leakiest in ...
# 14658    ANKARA (Reuters) - Iran rejected as  wrong  so...
# 15236    DUBAI (Reuters) - French President Emmanuel Ma...
# Name: text, Length: 8980, dtype: object

# %%
lemma_df=X_test['text'].progress_apply(lambda x:preprocess(x,'lemma'))
# Out:
# 100%|██████████| 8980/8980 [14:29<00:00, 10.32it/s]

# %%
lemma_df.head()
# Out:
#                                                        0    1
# 22216  donald trump white house chaos trying cover ru...  188
# 27917  donald trump presumptive gop nominee time reme...  274
# 25007  mike penny huge homophobe support ex gay conve...  235
# 1377   san francisco reuters california attorney gene...   57
# 32476  twisted reasoning come pelosi day especially p...   77

# %%
lemma_df.columns=['clean_text_lemma','text_length_lemma']
lemma_df.head()
# Out:
#                                         clean_text_lemma  text_length_lemma
# 22216  donald trump white house chaos trying cover ru...                188
# 27917  donald trump presumptive gop nominee time reme...                274
# 25007  mike penny huge homophobe support ex gay conve...                235
# 1377   san francisco reuters california attorney gene...                 57
# 32476  twisted reasoning come pelosi day especially p...                 77

# %%
X_test=pd.concat([X_test,lemma_df],axis=1)

# %%
X_test.head()
# Out:
#                                                     text  \
# 22216  Donald Trump s White House is in chaos, and th...
# 27917  Now that Donald Trump is the presumptive GOP n...
# 25007  Mike Pence is a huge homophobe. He supports ex...
# 1377   SAN FRANCISCO (Reuters) - California Attorney ...
# 32476  Twisted reasoning is all that comes from Pelos...
#
#                                         clean_text_lemma  text_length_lemma
# 22216  donald trump white house chaos trying cover ru...                188
# 27917  donald trump presumptive gop nominee time reme...                274
# 25007  mike penny huge homophobe support ex gay conve...                235
# 1377   san francisco reuters california attorney gene...                 57
# 32476  twisted reasoning come pelosi day especially p...                 77

# %%
X_test_bow=vocab.transform(X_test['clean_text_lemma'])

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train_bow,Y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred=classifier.predict(X_test_bow)

# %%
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
log_accuracy=(accuracy_score(Y_test,y_test_pred))
print(classification_report(Y_test,y_test_pred))
log_accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.83      4650
#            1       0.99      0.58      0.73      4330
#
#     accuracy                           0.80      8980
#    macro avg       0.86      0.79      0.78      8980
# weighted avg       0.85      0.80      0.79      8980
# 0.7957683741648107

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train_bow,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred=classifier.predict(X_test_bow)

# %%
DT_accuracy=(accuracy_score(Y_test,y_test_pred))
print(classification_report(Y_test,y_test_pred))
DT_accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.68      4650
#            1       0.98      0.01      0.02      4330
#
#     accuracy                           0.52      8980
#    macro avg       0.75      0.50      0.35      8980
# weighted avg       0.74      0.52      0.36      8980
# 0.5223830734966592

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train_bow,Y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred=classifier.predict(X_test_bow)

# %%
RF_accuracy=(accuracy_score(Y_test,y_test_pred))
print(classification_report(Y_test,y_test_pred))
RF_accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      4650
#            1       0.99      0.88      0.93      4330
#
#     accuracy                           0.94      8980
#    macro avg       0.94      0.94      0.94      8980
# weighted avg       0.94      0.94      0.94      8980
# 0.9378619153674833

# %%
from sklearn.svm import SVC
SVclassifier=SVC()
SVclassifier.fit(X_train_bow,Y_train)
# Out:
# SVC()

# %%
y_test_pred=SVclassifier.predict(X_test_bow)

# %%
SVC_accuracy=(accuracy_score(Y_test,y_test_pred))
print(classification_report(Y_test,y_test_pred))
SVC_accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81      4650
#            1       0.99      0.50      0.67      4330
#
#     accuracy                           0.76      8980
#    macro avg       0.84      0.75      0.74      8980
# weighted avg       0.83      0.76      0.74      8980
# 0.7594654788418709

# %%
from sklearn.neighbors import KNeighborsClassifier
KNclassifier=KNeighborsClassifier()
KNclassifier.fit(X_train_bow,Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred=KNclassifier.predict(X_test_bow)

# %%
kn_accuracy=(accuracy_score(Y_test,y_test_pred))
print(classification_report(Y_test,y_test_pred))
kn_accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.76      4650
#            1       0.78      0.64      0.70      4330
#
#     accuracy                           0.74      8980
#    macro avg       0.74      0.73      0.73      8980
# weighted avg       0.74      0.74      0.73      8980
# 0.7359688195991091

# %%
from sklearn.ensemble import BaggingClassifier
BAclassifier=BaggingClassifier()
BAclassifier.fit(X_train_bow,Y_train)
# Out:
# BaggingClassifier()

# %%
y_test_pred=BAclassifier.predict(X_test_bow)

# %%
BA_accuracy=(accuracy_score(Y_test,y_test_pred))
print(classification_report(Y_test,y_test_pred))
BA_accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.68      4650
#            1       1.00      0.00      0.01      4330
#
#     accuracy                           0.52      8980
#    macro avg       0.76      0.50      0.35      8980
# weighted avg       0.75      0.52      0.36      8980
# 0.5198218262806236

# %%
evaluation = pd.DataFrame({'Algorithms':['Linear Regression','Decision Tree','Random Forest','SVC','KNN','Bagging'],"Accuracy":[log_accuracy,DT_accuracy,RF_accuracy,SVC_accuracy,kn_accuracy,BA_accuracy]})

# %%
evaluation
# Out:
#           Algorithms  Accuracy
# 0  Linear Regression  0.795768
# 1      Decision Tree  0.522383
# 2      Random Forest  0.937862
# 3                SVC  0.759465
# 4                KNN  0.735969
# 5            Bagging  0.519822
